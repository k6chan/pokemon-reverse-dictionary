# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import spacy
import json

spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## Smogon

# %% [markdown]
# ### Tidy data

# %%
smogon_url = 'https://www.smogon.com/dex/sm/pokemon/' #most pokemon in this generation
smogon_text = requests.get(smogon_url).text
smogon_soup = BeautifulSoup(smogon_text,'html.parser')

# %%
smogon_javascript = smogon_soup.find_all('script', class_="", attrs={'type':'text/javascript'})[1]
left_brace_location = smogon_javascript.text.find('{')
smogon_json = smogon_javascript.text[left_brace_location:]
smogon_object = json.loads(smogon_json)
smogon_data = smogon_object['injectRpcs'][1][1]
smogon_pokemon = smogon_data['pokemon']
def is_standard(pokemon):
    return pokemon['isNonstandard'] == 'Standard' #fan-created Pokemon are labeled as Nonstandard
smogon_real_pokemon = list(filter(is_standard,smogon_pokemon))

# %%
pokemon_table = pd.DataFrame(data=smogon_real_pokemon)
pokemon_table.head()
# Out:
#          name  hp  atk  def  spa  spd  spe  weight  height            types  \
# 0   Bulbasaur  45   49   49   65   65   45     6.9     0.7  [Grass, Poison]
# 1     Ivysaur  60   62   63   80   80   60    13.0     1.0  [Grass, Poison]
# 2    Venusaur  80   82   83  100  100   80   100.0     2.0  [Grass, Poison]
# 3  Charmander  39   52   43   60   50   65     8.5     0.6           [Fire]
# 4  Charmeleon  58   64   58   80   65   80    19.0     1.1           [Fire]
#
#                  abilities formats isNonstandard  \
# 0  [Chlorophyll, Overgrow]    [LC]      Standard
# 1  [Chlorophyll, Overgrow]   [NFE]      Standard
# 2  [Chlorophyll, Overgrow]    [RU]      Standard
# 3     [Blaze, Solar Power]    [LC]      Standard
# 4     [Blaze, Solar Power]   [NFE]      Standard
#
#                                                  oob
# 0  {'dex_number': 1, 'evos': ['Ivysaur'], 'alts':...
# 1  {'dex_number': 2, 'evos': ['Venusaur'], 'alts'...
# 2  {'dex_number': 3, 'evos': [], 'alts': ['Venusa...
# 3  {'dex_number': 4, 'evos': ['Charmeleon'], 'alt...
# 4  {'dex_number': 5, 'evos': ['Charizard'], 'alts...

# %%
def get_nth_element(lst, n):
    if len(lst) > (n-1):
        return lst[n-1]
    else:
        return np.nan
    
def get_additional_information(oob, key):
    return oob[key]

pokemon_formats = pokemon_table['formats'].apply(get_nth_element, args=(1,))
pokemon_abilities_1 = pokemon_table['abilities'].apply(get_nth_element, args=(1,))
pokemon_abilities_2 = pokemon_table['abilities'].apply(get_nth_element, args=(2,))
pokemon_abilities_3 = pokemon_table['abilities'].apply(get_nth_element, args=(3,))
pokemon_abilities_4 = pokemon_table['abilities'].apply(get_nth_element, args=(4,))
pokemon_types_1 = pokemon_table['types'].apply(get_nth_element, args=(1,))
pokemon_types_2 = pokemon_table['types'].apply(get_nth_element, args=(2,))
pokemon_natdex = pokemon_table['oob'].apply(lambda oob: oob["dex_number"] if isinstance(oob,dict) else np.nan)
pokemon_evo = pokemon_table['oob'].apply(lambda oob: " ".join(oob["evos"]) if isinstance(oob,dict) else np.nan)

# %%
pokemon = pokemon_table.drop(
    columns=["types","abilities","oob","isNonstandard"]).assign(
    formats=pokemon_formats,ability_1=pokemon_abilities_1,
              ability_2=pokemon_abilities_2,ability_3=pokemon_abilities_3,
              ability_4=pokemon_abilities_4,type_1=pokemon_types_1,type_2=pokemon_types_2,
              nat_dex=pokemon_natdex, evos=pokemon_evo)
pokemon.head()
# Out:
#          name  hp  atk  def  spa  spd  spe  weight  height formats  \
# 0   Bulbasaur  45   49   49   65   65   45     6.9     0.7      LC
# 1     Ivysaur  60   62   63   80   80   60    13.0     1.0     NFE
# 2    Venusaur  80   82   83  100  100   80   100.0     2.0      RU
# 3  Charmander  39   52   43   60   50   65     8.5     0.6      LC
# 4  Charmeleon  58   64   58   80   65   80    19.0     1.1     NFE
#
#      ability_1    ability_2 ability_3 ability_4 type_1  type_2  nat_dex  \
# 0  Chlorophyll     Overgrow       NaN       NaN  Grass  Poison      1.0
# 1  Chlorophyll     Overgrow       NaN       NaN  Grass  Poison      2.0
# 2  Chlorophyll     Overgrow       NaN       NaN  Grass  Poison      3.0
# 3        Blaze  Solar Power       NaN       NaN   Fire     NaN      4.0
# 4        Blaze  Solar Power       NaN       NaN   Fire     NaN      5.0
#
#          evos
# 0     Ivysaur
# 1    Venusaur
# 2
# 3  Charmeleon
# 4   Charizard

# %% [markdown]
# ### Prepare for features

# %%
#some competitive terminology
smogon_dict = {}
smogon_dict["attack_discretized"] = pd.cut(pokemon["atk"], bins=2 ,labels=["weak", "strong"])
smogon_dict["spa_discretized"] = pd.cut(pokemon['spa'], bins=2, labels=["weak","strong"])
smogon_dict["def_discretized"] = pd.cut(pokemon["def"], bins=2 ,labels=["frail", "bulky"])
smogon_dict["spd_discretized"] = pd.cut(pokemon["spd"], bins=2 ,labels=["frail", "bulky"])
smogon_dict["spe_discretized"] = pd.cut(pokemon["spe"], bins=2 ,labels=["slow", "fast"])
smogon_dict["weight_discretized"] = pd.cut(pokemon["weight"], bins=2 ,labels=["light", "heavy"])
smogon_dict["height_discretized"] = pd.cut(pokemon["height"], bins=2 ,labels=["short", "tall"])

# %%
smogon_dict["abilities"] = pokemon_table["abilities"].str.join(" ")
smogon_dict["types"] = pokemon_table["types"].str.join(" ")
smogon_dict["evos"] = pokemon["evos"]

# %%
smogon_pokemon = pd.DataFrame(smogon_dict)
descriptions = smogon_pokemon.apply(lambda col: ' '.join(col.astype(str)), axis=1)
smogon_pokemon_descriptions = pd.DataFrame({"name": pokemon["name"], "nat_dex": pokemon["nat_dex"], "description": descriptions})
smogon_pokemon_descriptions.head()
# Out:
#          name  nat_dex                                        description
# 0   Bulbasaur      1.0  weak weak frail frail slow light short Chlorop...
# 1     Ivysaur      2.0  weak weak frail frail slow light short Chlorop...
# 2    Venusaur      3.0  weak weak frail frail slow light short Chlorop...
# 3  Charmander      4.0  weak weak frail frail slow light short Blaze S...
# 4  Charmeleon      5.0  weak weak frail frail slow light short Blaze S...

# %% [markdown]
# ----

# %% [markdown]
# ## Bulbapedia

# %%
bulbapedia_url = "https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number"
bulbapedia_text = requests.get(bulbapedia_url).text
bulbapedia_soup = BeautifulSoup(bulbapedia_text,'html.parser')

# %%
bulbapedia_ndex = bulbapedia_soup.find_all("td", {"style":"font-family:monospace,monospace"})
ndex = list(map(lambda n: n.text[1:], bulbapedia_ndex))
ndex_ser = pd.Series(ndex).astype(int)

ndex_ser.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
bulbapedia_rows = bulbapedia_soup.find_all(lambda tag: tag.name == 'td' and not tag.attrs)[:-1] # exclude the final td, which is not a Pokemon

bulbapedia_names = []

bulbapedia_thumbnails = []
for soup in bulbapedia_rows:
    img_search = soup.find('a')
    bulbapedia_names.append(img_search.get("href"))
    
    src_search = soup.find('img')
    if src_search is not None:
        bulbapedia_thumbnails.append(src_search.get("src"))
bulbapedia_names = bulbapedia_names[1::2]
bulbapedia_names_ser = pd.Series(bulbapedia_names)
# bulbapedia_names = bulbapedia_names_ser.unique() #remove duplicates
bulbapedia_names_ser = pd.Series(bulbapedia_names)
                                     
bulbapedia_thumbnails_ser = pd.Series(bulbapedia_thumbnails)
bulbapedia_thumbnails_ser = pd.Series(bulbapedia_thumbnails)

bulbapedia_dex = pd.DataFrame({"page":bulbapedia_names_ser, "thumbnail": bulbapedia_thumbnails_ser})
bulbapedia_dex_unique = bulbapedia_dex.iloc[bulbapedia_dex[["page"]].drop_duplicates().index].reset_index().drop(columns=["index"]) #remove alternate forms
bulbapedia_dex_unique.head()
# Out:
#                               page  \
# 0   /wiki/Bulbasaur_(Pok%C3%A9mon)
# 1     /wiki/Ivysaur_(Pok%C3%A9mon)
# 2    /wiki/Venusaur_(Pok%C3%A9mon)
# 3  /wiki/Charmander_(Pok%C3%A9mon)
# 4  /wiki/Charmeleon_(Pok%C3%A9mon)
#
#                                            thumbnail
# 0  //archives.bulbagarden.net/media/upload/thumb/...
# 1  //archives.bulbagarden.net/media/upload/thumb/...
# 2  //archives.bulbagarden.net/media/upload/thumb/...
# 3  //archives.bulbagarden.net/media/upload/thumb/...
# 4  //archives.bulbagarden.net/media/upload/thumb/...

# %%
bulbapedia_pokemon_table = bulbapedia_dex_unique.assign(ndex=ndex_ser, thumbnail="https:" + bulbapedia_dex_unique["thumbnail"])
bulbapedia_pokemon_table.head()
# Out:
#                               page  \
# 0   /wiki/Bulbasaur_(Pok%C3%A9mon)
# 1     /wiki/Ivysaur_(Pok%C3%A9mon)
# 2    /wiki/Venusaur_(Pok%C3%A9mon)
# 3  /wiki/Charmander_(Pok%C3%A9mon)
# 4  /wiki/Charmeleon_(Pok%C3%A9mon)
#
#                                            thumbnail  ndex
# 0  https://archives.bulbagarden.net/media/upload/...     1
# 1  https://archives.bulbagarden.net/media/upload/...     2
# 2  https://archives.bulbagarden.net/media/upload/...     3
# 3  https://archives.bulbagarden.net/media/upload/...     4
# 4  https://archives.bulbagarden.net/media/upload/...     5

# %%
CACHE = {}
vocab = spacy.load('en_core_web_sm')

def get_bulbapedia_biology(page_pokemon):
    if page_pokemon in CACHE:
        return CACHE[page_pokemon]
    page_root = "https://bulbapedia.bulbagarden.net"
    entry_text = requests.get(page_root + page_pokemon).text
    entry_soup = BeautifulSoup(entry_text,'html.parser')
    pokemon_text_lst = []
    biology_span = entry_soup.find("span",id="Biology").next_elements
    for i, element in enumerate(biology_span):
        if i == 0:
            continue
        if element.name == "h2": # next section
            break
        pokemon_text_lst.append(element.get_text(strip=True))
    pokemon_text = ' '.join(pokemon_text_lst).strip()
    doc = vocab(pokemon_text)
    tokens = set()
    for token in doc:
        if token.pos_ == 'NOUN':
            tokens.add(token.text)
    nouns = " ".join(tokens)
    CACHE[page_pokemon] = nouns
    return nouns

# %% [markdown]
# ### Prepare for merging

# %%
# removes alternate forms and Gen 8+ Pokemon
bulbapedia_smogon = bulbapedia_pokemon_table.assign(
    ndex = bulbapedia_pokemon_table["ndex"].astype("float64")).merge(
    smogon_pokemon_descriptions, how="inner", left_on="ndex", right_on="nat_dex")
bulbapedia_smogon = bulbapedia_smogon.assign(ndex=bulbapedia_smogon['ndex'].astype(int)).set_index("ndex")
bulbapedia_smogon.head()
# Out:
#                                  page  \
# ndex
# 1      /wiki/Bulbasaur_(Pok%C3%A9mon)
# 2        /wiki/Ivysaur_(Pok%C3%A9mon)
# 3       /wiki/Venusaur_(Pok%C3%A9mon)
# 4     /wiki/Charmander_(Pok%C3%A9mon)
# 5     /wiki/Charmeleon_(Pok%C3%A9mon)
#
#                                               thumbnail        name  nat_dex  \
# ndex
# 1     https://archives.bulbagarden.net/media/upload/...   Bulbasaur      1.0
# 2     https://archives.bulbagarden.net/media/upload/...     Ivysaur      2.0
# 3     https://archives.bulbagarden.net/media/upload/...    Venusaur      3.0
# 4     https://archives.bulbagarden.net/media/upload/...  Charmander      4.0
# 5     https://archives.bulbagarden.net/media/upload/...  Charmeleon      5.0
#
#                                             description
# ndex
# 1     weak weak frail frail slow light short Chlorop...
# 2     weak weak frail frail slow light short Chlorop...
# 3     weak weak frail frail slow light short Chlorop...
# 4     weak weak frail frail slow light short Blaze S...
# 5     weak weak frail frail slow light short Blaze S...

# %%
bulbapedia_smogon_descriptions_separate = bulbapedia_smogon.assign(biology = bulbapedia_smogon["page"].apply(get_bulbapedia_biology))

# %%
bulbapedia_smogon_tidy = bulbapedia_smogon_descriptions_separate.assign(
    description = bulbapedia_smogon_descriptions_separate["description"] + " " + bulbapedia_smogon_descriptions_separate["biology"]).drop(
    columns=["page", "biology","nat_dex"])

bulbapedia_smogon_tidy.head()
# Out:
#                                               thumbnail        name  \
# ndex
# 1     https://archives.bulbagarden.net/media/upload/...   Bulbasaur
# 2     https://archives.bulbagarden.net/media/upload/...     Ivysaur
# 3     https://archives.bulbagarden.net/media/upload/...    Venusaur
# 4     https://archives.bulbagarden.net/media/upload/...  Charmander
# 5     https://archives.bulbagarden.net/media/upload/...  Charmeleon
#
#                                             description
# ndex
# 1     weak weak frail frail slow light short Chlorop...
# 2     weak weak frail frail slow light short Chlorop...
# 3     weak weak frail frail slow light short Chlorop...
# 4     weak weak frail frail slow light short Blaze S...
# 5     weak weak frail frail slow light short Blaze S...

# %%
# bulbapedia_smogon_tidy.to_csv("bulbapedia_smogon_data.csv")

# %%
# page_root = "https://bulbapedia.bulbagarden.net"
# page_pokemon = "/wiki/Bulbasaur_(Pok%C3%A9mon)"
# entry_text = requests.get(page_root + page_pokemon).text

# %%
# entry_soup = BeautifulSoup(entry_text,'html.parser')
# entry_soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Bulbasaur (Pokémon) - Bulbapedia, the community-driven Pokémon encyclopedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"3044eef1a643d666c877620c","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Bulbasaur_(Pokémon)","wgTitle":"Bulbasaur (Pokémon)","wgCurRevisionId":3669068,"wgRevisionId":3669068,"wgArticleId":1161,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Generation I Pokémon","Grass-type Pokémon","Poison-type Pokémon","Dual-type Pokémon","Pokémon with a gender ratio of seven males to one female","Pokémon in the Medium Slow experience group","Green-colored Pokémon","Body style 08 Pokémon","Monster group Pokémon","Grass group Pokémon",
# "Pokémon in the Kanto Pokédex","Pokémon in the Johto Pokédex","Pokémon in the Kalos Pokédex","Pokémon in the Galar Pokédex","Pokémon with wild held items","Pokémon with a base stat total of 318","Pokémon whose Special stat became both Special Attack and Special Defense","Pokémon with 17 max performance stars","Body size 1 Pokémon","Pokémon that are part of a three-stage evolutionary line","Starter Pokémon","Mystery Dungeon starters","Anime starter Pokémon"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Bulbasaur_(Pokémon)","wgRelevantArticleId":1161,"wgIsProbablyEditable":!1,"wgRelevantPageIsProbablyEditable":!1,"wgRestrictionEdit":[],"wgRestrictionMove":["sysop"],"wgMFDisplayWikibaseDescriptions":{"search":!1,"nearby":!1,"watchlist":!1,"tagline":!1}};RLSTATE={"site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","jquery.tablesorter.styles":
# "ready","mediawiki.toc.styles":"ready","mediawiki.skinning.content.externallinks":"ready","skins.monobook.responsive":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","skins.monobook.mobile"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});</script>
# <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cjquery.tablesorter.styles%7Cmediawiki.skinning.content.externallinks%7Cmediawiki.toc.styles%7Cskins.monobook.responsive&amp;only=styles&amp;skin=monobook" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=monobook"></script>
# <!--[if lt IE 9]><link rel="stylesheet" href="/w/skins/MonoBook/resources/screen-desktop.css?9f2ce" media="screen"/><![endif]--><link href="//bulba-ad-host-website.azurewebsites.net/Content/customstyles.css?v=2" rel="stylesheet"/><link href="//bulbapedia.bulbagarden.net/w/skins/MonoBook/resources/newdesign.css" rel="stylesheet"/><link href="//bulbapedia.bulbagarden.net/w/skins/MonoBook/resources/customstyles.css" rel="stylesheet"/><link href="//bulbapedia.bulbagarden.net/w/skins/MonoBook/resources/adrow-styles.css" rel="stylesheet"/><link href="//ahost2.bulbagarden.net/Content/bulbagarden/styles/globalnavbar.css?v=2" rel="stylesheet"/>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=monobook" rel="stylesheet"/>
# <meta content="MediaWiki 1.35.2" name="generator"/>
# <meta content="https://archives.bulbagarden.net/media/upload/f/fb/0001Bulbasaur.png" property="og:image"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.25, maximum-scale=5.0" name="viewport"/>
# <link href="https://m.bulbapedia.bulbagarden.net/wiki/Bulbasaur_(Pok%C3%A9mon)" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Bulbapedia (en)" type="application/opensearchdescription+xml"/>
# <link href="https://bulbapedia.bulbagarden.net/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://creativecommons.org/licenses/by-nc-sa/2.5/" rel="license"/>
# <link href="https://bulbapedia.bulbagarden.net/wiki/Bulbasaur_(Pok%C3%A9mon)" rel="canonical"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-XCGG53D4E3"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-XCGG53D4E3');
#   gtag('config', 'UA-326511-18');
# </script>
# <script>
# (function(w, d) {
# w.adthrive = w.adthrive || {};
# w.adthrive.cmd = w.adthrive.cmd || [];
# w.adthrive.plugin = 'adthrive-ads-manual';
# w.adthrive.host = 'ads.adthrive.com';
# var s = d.createElement('script');
# s.async = true;
# s.referrerpolicy='no-referrer-when-downgrade';
# s.src = 'https://' + w.adthrive.host + '/sites/630428a76245162875c78210/ads.min.js?referrer=' + w.encodeURIComponent(w.location.href) + '&cb=' + (Math.floor(Math.random() * 100) + 1);
# var n = d.getElementsByTagName('script')[0];
# n.parentNode.insertBefore(s, n);
# })(window, document);
# </script>
# <script src="//ahost.bulbagarden.net/Content/bulbapediascript.js" type="text/javascript"></script>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://fonts.googleapis.com/css2?family=Public+Sans:ital,wght@0,100..900;1,100..900&amp;display=swap" rel="stylesheet"/>
# <!--[if lt IE 9]><script src="/w/resources/lib/html5shiv/html5shiv.js"></script><![endif]-->
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Bulbasaur_Pokémon rootpage-Bulbasaur_Pokémon skin-monobook action-view minerva--history-page-action-enabled"> <div class="bg-global-menu bg-bulbapedia-menu">
# <a class="bg-global-nav-logo" href="https://bulbagarden.net"></a>
# <nav class="bg-global-nav">
# <ul class="bg-global-nav-primary">
# <li class="bg-global-nav-primary-item">
# <a class="bg-global-nav-primary-link" href="https://bulbagarden.net">News</a>
# </li>
# <li class="bg-global-nav-primary-item bg-global-nav-primary-haschildren">
# <a class="bg-global-nav-primary-link bg-global-nav-primary-toggle selected" href="https://bulbapedia.bulbagarden.net/">Bulbapedia</a>
# <ul class="bg-global-nav-primary-children">
# <li class="bg-global-nav-secondary row">
# <ul>
# <li class="bg-global-nav-secondary-item bulbapedia">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/">Bulbapedia main page</a>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">Pokémon</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/List_of_Pokémon_by_National_Pokédex_number">National Pokédex</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_name">By Name</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Legendary_Pok%C3%A9mon">Legendary</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Mythical_Pok%C3%A9mon">Mythical</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Event_Pok%C3%A9mon">Event Pokémon</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Noble_Pokémon">Noble Pokémon</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Gigantamax">Gigantamax</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Alpha_Pokémon">Alpha Pokémon</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon">more...</a>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">Mechanics</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Type">Types</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Type#Type_chart">Type Chart</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Abilities">Abilities</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Nature#List_of_Natures">Nature</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Status_condition">Status Conditions</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Moves">Moves</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Items">Items</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Game_mechanics">more...</a>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">Games</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Walkthroughs">Walkthroughs</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Pokémon_Legends:_Arceus">Pokémon Legends: Arceus</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Pokémon_Brilliant_Diamond_and_Shining_Pearl">Pokémon Brilliant Diamond and Shining Pearl</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Pok%C3%A9mon_Sword_and_Shield">Sword &amp; Shield</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Spin-off_Pok%C3%A9mon_games">Spin Offs</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Pok%C3%A9mon_GO">GO</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Games">all games...</a>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">TCG</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Pok%C3%A9mon_Trading_Card_Game">About</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Pok%C3%A9mon_Trading_Card_Game#How_to_play">How to Play</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Rotation_(TCG)">Rotation</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Promotional_cards_(TCG)">Promotional Cards</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Brilliant_Stars_(TCG)">Brilliant Stars</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Fusion_Strike_(TCG)">Fusion Strike</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_Trading_Card_Game_expansions">all expansions...</a>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">Anime &amp; Manga</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Ash_Ketchum">Ash Ketchum</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Anime">Anime</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/List_of_anime_characters">Anime Characters</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_Journeys:_The_Series_episodes">Journeys Episodes</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Pok%C3%A9mon_movie#List_of_movies">Movies</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Category:Manga">Manga</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-primary-item">
# <a class="bg-global-nav-primary-link @Selected(" forums")"="" href="https://forums.bulbagarden.net/">Forums</a>
# </li>
# <li class="bg-global-nav-primary-item">
# <a class="bg-global-nav-primary-link" href="https://discord.gg/bulbagarden">Discord</a>
# </li>
# <li class="bg-global-nav-primary-item bg-global-nav-primary-haschildren">
# <a class="bg-global-nav-primary-link bg-global-nav-primary-toggle" href="#bulbapedia">More</a>
# <ul class="bg-global-nav-primary-children">
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">Social</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://www.youtube.com/user/Bulbagarden" rel="noopener" target="_blank">Youtube</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://twitter.com/Bulbagarden" rel="noopener" target="_blank">Twitter</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://www.facebook.com/Bulbagarden/" rel="noopener" target="_blank">Facebook</a>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">Apps</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://play.google.com/store/apps/details?id=org.bulbagarden.alpha&amp;hl=en&amp;gl=US" rel="noopener" target="_blank">Android</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://apps.apple.com/us/app/bulbapedia-wiki-for-pok%C3%A9mon/id1242159382" rel="noopener" target="_blank">iOS</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="bg-global-nav-primary utilities">
# <li class="bg-global-nav-primary-item bg-global-nav-primary-haschildren">
# <a class="bg-global-nav-primary-link bg-global-nav-primary-toggle" href="#bulbapedia">Editors</a>
# <ul class="bg-global-nav-primary-children">
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">Bulbapedia</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Bulbapedia:Editor%27s_Hub">Editor's hub</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://www.mediawiki.org/wiki/Help:Contents">Help</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Bulbapedia:FAQ">FAQ</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://forums.bulbagarden.net/index.php?forums/bulbawiki-forum.195/">Bulbawiki forum</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Special:RecentChanges">Recent changes</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Special:Random">Random Page</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Special:SpecialPages">Special pages</a>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">Archives</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://archives.bulbagarden.net/wiki/Main_Page">Main Page</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://archives.bulbagarden.net/wiki/Archives:FAQ">FAQ</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://archives.bulbagarden.net/wiki/Archives:To-do_list">To-do list</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://archives.bulbagarden.net/wiki/Special:Upload">Upload file</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://archives.bulbagarden.net/wiki/Special:RecentChanges">Recent Changes</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://archives.bulbagarden.net/wiki/Special:Log/upload">Recent Uploads</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://archives.bulbagarden.net/wiki/Special:Random/File">Random File</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-primary-item bg-global-nav-primary-haschildren">
# <a class="bg-global-nav-primary-link bg-global-nav-primary-toggle" href="#account">Account</a>
# <ul class="bg-global-nav-primary-children">
# <li class="bg-global-nav-secondary row">
# <ul>
# <li class="bg-global-nav-secondary-item bulbapedia">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/w/index.php?title=Special:UserLogin&amp;returnto=Main+Page">Bulbapedia login</a>
# </li>
# <li class="bg-global-nav-secondary-item forums">
# <a class="bg-global-nav-secondary-link" href="https://forums.bulbagarden.net/index.php?login/">Forum login</a>
# </li>
# </ul>
# </li>
# <li class="bg-global-nav-secondary">
# <ul>
# <li class="bg-global-nav-secondary-item header">New Accounts</li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://bulbapedia.bulbagarden.net/wiki/Special:CreateAccount">Create Bulbapedia Account</a>
# </li>
# <li class="bg-global-nav-secondary-item">
# <a class="bg-global-nav-secondary-link" href="https://forums.bulbagarden.net/index.php?register/">Create Forum Account</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </nav>
# <div class="bg-global-nav-primary-link menu" id="bgMenuToggle">Menu</div>
# <div class="bg-global-nav-search-wrapper">
# <form action="/wiki/index.php" id="searchform">
# <input name="title" type="hidden" value="Special:Search"/>
# <input accesskey="f" autocomplete="off" class="bg-global-nav-search-input" id="searchInput" name="search" placeholder="Search Bulbapedia" title="Search Bulbapedia [alt-shift-f]" type="search"/>
# <input class="searchButton" id="searchGoButton" name="go" style="display: none;" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
# <input class="searchButton" id="mw-searchButton" name="fulltext" style="display: none;" title="Search the pages for this text" type="submit" value="Search"/>
# </form>
# </div>
# </div><div id="globalWrapper"><div id="column-content"><div class="mw-body" id="content" role="main"><div aria-labelledby="p-cactions-label" class="portlet" id="p-cactions" role="navigation"><h3 dir="ltr" id="p-cactions-label" lang="en">Page actions</h3><div class="pBody"><ul dir="ltr" lang="en"><li class="selected" id="ca-nstab-main"><a accesskey="c" href="/wiki/Bulbasaur_(Pok%C3%A9mon)" title="View the content page [c]">Article</a></li><li id="ca-talk"><a accesskey="t" href="/wiki/Talk:Bulbasaur_(Pok%C3%A9mon)" rel="discussion" title="Discussion about the content page [t]">Discussion</a></li><li id="ca-viewsource"><a accesskey="e" href="/w/index.php?title=Bulbasaur_(Pok%C3%A9mon)&amp;action=edit" title="This page is protected.
# You can view its source [e]">View source</a></li><li id="ca-history"><a accesskey="h" href="/w/index.php?title=Bulbasaur_(Pok%C3%A9mon)&amp;action=history" title="Past revisions of this page [h]">History</a></li></ul></div></div><div aria-labelledby="p-cactions-mobile-label" class="portlet" id="p-cactions-mobile" role="navigation"><h3 dir="ltr" id="p-cactions-mobile-label" lang="en">Page actions</h3><div class="pBody"><ul dir="ltr" lang="en"><li class="selected" id="ca-nstab-main-mobile"><a href="/wiki/Bulbasaur_(Pok%C3%A9mon)" title="Article">Article</a></li><li id="ca-talk-mobile"><a href="/wiki/Talk:Bulbasaur_(Pok%C3%A9mon)" rel="discussion" title="Discussion">Discussion</a></li><li id="ca-more"><a href="#p-cactions">More</a></li><li id="ca-tools"><a href="#p-tb" title="Tools">Tools</a></li><li id="ca-languages"><a href="#p-lang" title="In other languages">In other languages</a></li></ul></div></div><a id="top"></a><div class="mw-body-content" id="siteNotice"><div dir="ltr" id="localNotice" lang="en"><div class="noticebar roundy plainlinks" style="padding:0px;">Please remember to follow the <a href="/wiki/Bulbapedia:Manual_of_style" title="Bulbapedia:Manual of style">manual of style</a> and <a href="/wiki/Bulbapedia:Code_of_conduct" title="Bulbapedia:Code of conduct">code of conduct</a> at all times.<br/>Check the <a class="external text" href="https://bulbagarden.net/" rel="nofollow">Bulbagarden home page</a> for up-to-date Pokémon news and discuss it on the <a class="external text" href="https://forums.bulbagarden.net/index.php" rel="nofollow">forums</a> or in the <a class="external text" href="https://discord.gg/bulbagarden" rel="nofollow">Bulbagarden Discord server</a>.</div></div></div><div class="mw-indicators mw-body-content">
# </div>
# <div id="videocontainer" style="padding-bottom:10px;margin: 0 auto;min-width: 400px;width: 50vh;max-width: 700px;"></div><h1 class="firstHeading" id="firstHeading" lang="en">Bulbasaur (Pokémon)</h1><div class="mw-body-content" id="bodyContent"><div id="siteSub">From Bulbapedia, the community-driven Pokémon encyclopedia.</div><div dir="ltr" id="contentSub" lang="en"></div><div id="jump-to-nav"></div><a class="mw-jump-link" href="#column-one">Jump to navigation</a><a class="mw-jump-link" href="#searchInput">Jump to search</a><div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><table style="background: #78C850; width: 100%; border: 3px solid #682A68; margin-bottom: 7px; border-radius: 20px; -moz-border-radius: 20px; -webkit-border-radius: 20px; -khtml-border-radius: 20px; -icab-border-radius: 20px; -o-border-radius: 20px;">
# <tbody><tr>
# <td colspan="3" style="text-align: center; background: #FFF; border-top-left-radius: 15px; -moz-border-radius-topleft: 15px; -webkit-border-top-left-radius: 15px; -khtml-border-top-left-radius: 15px; -icab-border-top-left-radius: 15px; -o-border-top-left-radius: 15px; border-top-right-radius: 15px; -moz-border-radius-topright: 15px; -webkit-border-top-right-radius: 15px; -khtml-border-top-right-radius: 15px; -icab-border-top-right-radius: 15px; -o-border-top-right-radius: 15px;">For Pokémon GO information on this species, see <a href="/wiki/Bulbasaur_(Pok%C3%A9mon)#Pok.C3.A9mon_GO" title="Bulbasaur (Pokémon)">the game's section</a>.
# </td></tr>
# <tr>
# <td style="width:45%; background: #A7DB8D;">
# <table style="width:100%; background: #A7DB8D; border-top-left-radius: 15px; -moz-border-radius-topleft: 15px; -webkit-border-top-left-radius: 15px; -khtml-border-top-left-radius: 15px; -icab-border-top-left-radius: 15px; -o-border-top-left-radius: 15px; border-bottom-left-radius: 15px; -moz-border-radius-bottomleft: 15px; -webkit-border-bottom-left-radius: 15px; -khtml-border-bottom-left-radius: 15px; -icab-border-bottom-left-radius: 15px; -o-border-bottom-left-radius: 15px;">
# <tbody><tr>
# <td style="text-align: right"><a href="/wiki/Miraidon_(Pok%C3%A9mon)" title="Miraidon (Pokémon)"><span style="color:#000;">←</span></a>
# </td>
# <td style="text-align: center"><a href="/wiki/Miraidon_(Pok%C3%A9mon)" title="Miraidon (Pokémon)"><img alt="1008Miraidon.png" decoding="async" height="40" loading="lazy" src="//archives.bulbagarden.net/media/upload/thumb/1/1c/1008Miraidon.png/40px-1008Miraidon.png" srcset="//archives.bulbagarden.net/media/upload/thumb/1/1c/1008Miraidon.png/60px-1008Miraidon.png 1.5x, //archives.bulbagarden.net/media/upload/thumb/1/1c/1008Miraidon.png/80px-1008Miraidon.png 2x" width="40"/></a>
# </td>
# <td style="text-align: right"><a href="/wiki/Miraidon_(Pok%C3%A9mon)" title="Miraidon (Pokémon)"><span style="color:#000;">#1008: Miraidon</span></a>
# </td></tr></tbody></table>
# </td>
# <td style="background: #A7DB8D;">
# <table style="background: #A7DB8D; width:100%;">
# <tbody><tr>
# <td style="text-align: center"><a href="/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number" title="List of Pokémon by National Pokédex number"><span style="color:#000;">Pokémon</span></a>
# </td></tr></tbody></table>
# </td>
# <td style="width:45%; background: #A7DB8D;">
# <table style="width:100%; background: #A7DB8D; border-top-right-radius: 15px; -moz-border-radius-topright: 15px; -webkit-border-top-right-radius: 15px; -khtml-border-top-right-radius: 15px; -icab-border-top-right-radius: 15px; -o-border-top-right-radius: 15px; border-bottom-right-radius: 15px; -moz-border-radius-bottomright: 15px; -webkit-border-bottom-right-radius: 15px; -khtml-border-bottom-right-radius: 15px; -icab-border-bottom-right-radius: 15px; -o-border-bottom-right-radius: 15px;">
# <tbody><tr>
# <td style="text-align: left"><a href="/wiki/Ivysaur_(Pok%C3%A9mon)" title="Ivysaur (Pokémon)"><span style="color:#000;">#0002: Ivysaur</span></a>
# </td>
# <td style="text-align: center"><a href="/wiki/Ivysaur_(Pok%C3%A9mon)" title="Ivysaur (Pokémon)"><img alt="0002Ivysaur.png" decoding="async" height="40" loading="lazy" src="//archives.bulbagarden.net/media/upload/thumb/8/81/0002Ivysaur.png/40px-0002Ivysaur.png" srcset="//archives.bulbagarden.net/media/upload/thumb/8/81/0002Ivysaur.png/60px-0002Ivysaur.png 1.5x, //archives.bulbagarden.net/media/upload/thumb/8/81/0002Ivysaur.png/80px-0002Ivysaur.png 2x" width="40"/></a>
# </td>
# <td style="text-align: left"><a href="/wiki/Ivysaur_(Pok%C3%A9mon)" title="Ivysaur (Pokémon)"><span style="color:#000;">→</span></a>
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td colspan="3" style="text-align: center; background: #FFF; border-bottom-left-radius: 15px; -moz-border-radius-bottomleft: 15px; -webkit-border-bottom-left-radius: 15px; -khtml-border-bottom-left-radius: 15px; -icab-border-bottom-left-radius: 15px; -o-border-bottom-left-radius: 15px; border-bottom-right-radius: 15px; -moz-border-radius-bottomright: 15px; -webkit-border-bottom-right-radius: 15px; -khtml-border-bottom-right-radius: 15px; -icab-border-bottom-right-radius: 15px; -o-border-bottom-right-radius: 15px;">This article is about the species. For a specific instance of this species, see <a class="mw-disambig" href="/wiki/Bulbasaur_(disambiguation)" title="Bulbasaur (disambiguation)">Bulbasaur (disambiguation)</a>.
# </td></tr></tbody></table>
# <table class="roundy" style="float:right; text-align:center; width:33%; max-width:420px; background: #78C850; border: 2px solid #682A68; padding:2px;">
# <tbody><tr>
# <td colspan="2">
# <table class="roundy" style="background:#A7DB8D; padding:2px; border-spacing:3px;" width="100%">
# <tbody><tr>
# <td class="roundy" style="background:#FFF;" width="75%">
# <table style="background:none;" width="100%">
# <tbody><tr>
# <td width="50%"><big><big><b>Bulbasaur</b></big></big><br/><a href="/wiki/Pok%C3%A9mon_category" title="Pokémon category"><span style="color:#000;">Seed Pokémon</span></a>
# </td>
# <td><span lang="ja"><b>フシギダネ</b></span><br/><i>Fushigidane</i>
# </td></tr></tbody></table>
# </td>
# <th class="roundy" style="background:#FFF;" width="25%"><big><big><a href="/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number" title="List of Pokémon by National Pokédex number"><span style="color:#000;">#0001</span></a></big></big>
# </th></tr>
# <tr>
# <td colspan="2">
# <table class="roundy" style="background:#FFF;" width="100%">
# <tbody><tr>
# <td colspan="4"><a class="image" href="/wiki/File:0001Bulbasaur.png" title="Bulbasaur"><img alt="Bulbasaur" decoding="async" height="250" loading="lazy" src="//archives.bulbagarden.net/media/upload/thumb/f/fb/0001Bulbasaur.png/250px-0001Bulbasaur.png" srcset="//archives.bulbagarden.net/media/upload/thumb/f/fb/0001Bulbasaur.png/375px-0001Bulbasaur.png 1.5x, //archives.bulbagarden.net/media/upload/thumb/f/fb/0001Bulbasaur.png/500px-0001Bulbasaur.png 2x" width="250"/></a>
# </td></tr>
# <tr style="display:none;">
# <td colspan="1">
# </td>
# <td colspan="2" style="display:none;">
# </td>
# <td colspan="1" style="display:none;">
# </td></tr>
# <tr style="display:none;">
# <td colspan="2" style="display:none;"><br/><small></small>
# </td>
# <td colspan="2"><br/><small></small>
# </td>
# <td colspan="2" style="display:none;"><br/><small></small>
# </td></tr>
# <tr>
# <td colspan="4"><a class="extiw" href="https://archives.bulbagarden.net/wiki/Category:Bulbasaur" title="a:Category:Bulbasaur">Images on the Bulbagarden Archives</a>
# </td></tr></tbody></table>
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="roundy" colspan="2" style="background:#A7DB8D; padding:2px;"><b><a href="/wiki/Type" title="Type"><span style="color:#000;">Type</span></a></b>
# <table class="roundy" style="background: #FFF; padding-top: 3px;" width="100%">
# <tbody><tr>
# <td>
# <table style="margin:auto; background:none;">
# <tbody><tr>
# <td style="font-size: 85%; line-height:12px; background: #78C850; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a href="/wiki/Grass_(type)" title="Grass (type)"><span style="color:#FFF;"><b>Grass</b></span></a>
# </td>
# <td style="font-size: 85%; line-height:12px; background: #A040A0; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a href="/wiki/Poison_(type)" title="Poison (type)"><span style="color:#FFF;"><b>Poison</b></span></a>
# </td></tr></tbody></table>
# </td>
# <td style="display: none; width:50%;">
# <table style="margin:auto; background:none;">
# <tbody><tr>
# <td style="font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td>
# <td style="display: none; font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td></tr></tbody></table><small></small>
# </td>
# <td style="display: none;">
# <table style="margin:auto; background:none;">
# <tbody><tr>
# <td style="font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td>
# <td style="display: none; font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td></tr></tbody></table><small></small>
# </td>
# <td style="display: none;">
# <table style="margin:auto; background:none;">
# <tbody><tr>
# <td style="font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td>
# <td style="display: none; font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td></tr></tbody></table><small></small>
# </td>
# <td style="display: none;">
# <table style="margin:auto; background:none;">
# <tbody><tr>
# <td style="font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td>
# <td style="display: none; font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td></tr></tbody></table><small></small>
# </td>
# <td style="display: none;">
# <table style="margin:auto; background:none;">
# <tbody><tr>
# <td style="font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td>
# <td style="display: none; font-size: 85%; line-height:12px; background: #68A090; border-radius: 2px; -moz-border-radius: 2px; -webkit-border-radius: 2px; -khtml-border-radius: 2px; -icab-border-radius: 2px; -o-border-radius: 2px;" width="45px"><a class="mw-redirect" href="/wiki/Unknown_(type)" title="Unknown (type)"><span style="color:#FFF;"><b>Unknown</b></span></a>
# </td></tr></tbody></table><small></small>
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="roundy" colspan="2" style="background:#A7DB8D;"><b><a href="/wiki/Ability" title="Ability"><span style="color:#000;">Abilities</span></a></b>
# <table class="roundy" style="background:#FFF;" width="100%">
# <tbody><tr>
# <td width="50%"><a href="/wiki/Overgrow_(Ability)" title="Overgrow (Ability)"><span style="color:#000;">Overgrow</span></a>
# </td>
# <td style="display: none" width="50%"><a href="/wiki/Cacophony_(Ability)" title="Cacophony (Ability)"><span style="color:#000;">Cacophony</span></a><br/><small></small>
# </td>
# <td colspan="1" style="display: none" width="50%"><a href="/wiki/Cacophony_(Ability)" title="Cacophony (Ability)"><span style="color:#000;">Cacophony</span></a><br/><small></small>
# </td>
# <td colspan="1" width="50%"><a href="/wiki/Chlorophyll_(Ability)" title="Chlorophyll (Ability)"><span style="color:#000;">Chlorophyll</span></a><br/><small> Hidden Ability</small>
# </td>
# <td style="display: none" width="50%"><a href="/wiki/Cacophony_(Ability)" title="Cacophony (Ability)"><span style="color:#000;">Cacophony</span></a><br/><small> Hidden Ability</small>
# </td>
# <td colspan="1" style="display: none" width="50%"><a href="/wiki/Cacophony_(Ability)" title="Cacophony (Ability)"><span style="color:#000;">Cacophony</span></a><br/><small></small>
# </td>
# <td style="display: none" width="50%"><a href="/wiki/Cacophony_(Ability)" title="Cacophony (Ability)"><span style="color:#000;">Cacophony</span></a><br/><small></small>
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="roundy" style="background:#A7DB8D;" width="50%"><b><a href="/wiki/List_of_Pok%C3%A9mon_by_gender_ratio" title="List of Pokémon by gender ratio"><span style="color:#000;">Gender ratio</span></a></b>
# <table class="roundy" style="background:#FFF;" width="100%">
# <tbody><tr>
# <td style="display:none;"><span style="color:#000;">Unknown</span>
# </td>
# <td style=""><div class="statbar" style="float:left;background:#3355FF; border-top-left-radius: 20px; -moz-border-radius-topleft: 20px; -webkit-border-top-left-radius: 20px; -khtml-border-top-left-radius: 20px; -icab-border-top-left-radius: 20px; -o-border-top-left-radius: 20px; border-bottom-left-radius: 20px; -moz-border-radius-bottomleft: 20px; -webkit-border-bottom-left-radius: 20px; -khtml-border-bottom-left-radius: 20px; -icab-border-bottom-left-radius: 20px; -o-border-bottom-left-radius: 20px; color:#FFF; height:10px; width:86%; border: 0.5px solid black; border-right-width:0px; overflow: hidden;"></div><div class="statbar" style="float:left;background:#FF77DD; border-top-right-radius: 20px; -moz-border-radius-topright: 20px; -webkit-border-top-right-radius: 20px; -khtml-border-top-right-radius: 20px; -icab-border-top-right-radius: 20px; -o-border-top-right-radius: 20px; border-bottom-right-radius: 20px; -moz-border-radius-bottomright: 20px; -webkit-border-bottom-right-radius: 20px; -khtml-border-bottom-right-radius: 20px; -icab-border-bottom-right-radius: 20px; -o-border-bottom-right-radius: 20px; color:#000; height:10px; width:11%; border: 0.5px solid black; overflow: hidden; border-left-width:0px;"></div>
# </td></tr>
# <tr style="">
# <td><a href="/wiki/Category:Pok%C3%A9mon_with_a_gender_ratio_of_seven_males_to_one_female" title="Category:Pokémon with a gender ratio of seven males to one female"><span style="color:#0000FF;">87.5% male</span><span style="color:#000;">,</span> <span style="color:#FF6060;">12.5% female</span></a>
# </td></tr></tbody></table>
# </td>
# <td class="roundy" style="background:#A7DB8D;"><b><a href="/wiki/Catch_rate" title="Catch rate"><span style="color:#000;">Catch rate</span></a></b>
# <table class="roundy" style="background:#FFF; padding-top:0.6em; padding-bottom:0.6em;" width="100%">
# <tbody><tr>
# <td>45 <small>(<span class="explain" title="When an ordinary Poké Ball is thrown at full health in Generation VII">11.9%</span>)</small>
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="roundy" colspan="2" style="background:#A7DB8D;"><b><a href="/wiki/Pok%C3%A9mon_breeding" title="Pokémon breeding"><span style="color:#000;">Breeding</span></a></b>
# <table style="border-collapse:collapse;" width="100%">
# <tbody><tr>
# <td width="50%"><b><a href="/wiki/Egg_Group" title="Egg Group"><span style="color:#000;">Egg Groups</span></a></b>
# <table class="roundy" style="background:#fff;" width="100%">
# <tbody><tr>
# <td><a href="/wiki/Monster_(Egg_Group)" title="Monster (Egg Group)"><span style="color:#000;">Monster</span></a> and <a href="/wiki/Grass_(Egg_Group)" title="Grass (Egg Group)"><span style="color:#000;">Grass</span></a>
# </td></tr></tbody></table>
# </td>
# <td><b><a href="/wiki/Egg_cycle" title="Egg cycle"><span style="color:#000;">Hatch time</span></a></b>
# <table class="roundy" style="background:#fff;" width="100%">
# <tbody><tr>
# <td>5140 - 5396 <small>steps</small>
# </td></tr></tbody></table>
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="roundy" style="background:#A7DB8D;"><b><a href="/wiki/List_of_Pok%C3%A9mon_by_height" title="List of Pokémon by height"><span style="color:#000;">Height</span></a></b>
# <table class="roundy" style="background:#FFF;" width="100%">
# <tbody><tr>
# <td width="50%">2'04"
# </td>
# <td width="50%">0.7 m
# </td></tr>
# <tr style="display:none;">
# <td colspan="2" style="line-height:8pt;"><small>Bulbasaur</small>
# </td></tr>
# <tr style="display:none;">
# <td width="50%">0'0"
# </td>
# <td width="50%">0 m
# </td></tr>
# <tr style="display:none;">
# <td colspan="2" style="line-height:8pt;"><small>{{{form2}}}</small>
# </td></tr>
# <tr style="display:none;">
# <td width="50%">0'0"
# </td>
# <td width="50%">0 m
# </td></tr>
# <tr style="display:none;">
# <td colspan="2" style="line-height:8pt;"><small>{{{form3}}}</small>
# </td></tr>
# <tr style="display:none;">
# <td width="50%">0'0"
# </td>
# <td width="50%">0 m
# </td></tr>
# <tr style="display:none;">
# <td colspan="2" style="line-height:8pt;"><small>{{{form4}}}</small>
# </td></tr></tbody></table>
# </td>
# <td class="roundy" style="background:#A7DB8D;"><b><a href="/wiki/Weight" title="Weight"><span style="color:#000;">Weight</span></a></b>
# <table class="roundy" style="background:#FFF;" width="100%">
# <tbody><tr>
# <td width="50%">15.2 lbs.
# </td>
# <td width="50%">6.9 kg
# </td></tr>
# <tr style="display:none;">
# <td colspan="2" style="line-height:8pt;"><small>Bulbasaur</small>
# </td></tr>
# <tr style="display:none;">
# <td width="50%">0 lbs.
# </td>
# <td width="50%">0 kg
# </td></tr>
# <tr style="display:none;">
# <td colspan="2" style="line-height:8pt;"><small>{{{form2}}}</small>
# </td></tr>
# <tr style="display:none;">
# <td width="50%">0 lbs.
# </td>
# <td width="50%">0 kg
# </td></tr>
# <tr style="display:none;">
# <td colspan="2" style="line-height:8pt;"><small>{{{form3}}}</small>
# </td></tr>
# <tr style="display:none;">
# <td width="50%">0 lbs.
# </td>
# <td width="50%">0 kg
# </td></tr>
# <tr style="display:none;">
# <td colspan="2" style="line-height:8pt;"><small>{{{form4}}}</small>
# </td></tr></tbody></table>
# </td></tr>
# <tr style="display:none;">
# <td class="roundy" colspan="2" style="background:#A7DB8D;"><b><a href="/wiki/Mega_Stone" title="Mega Stone"><span style="color:#000;">Mega Stone</span></a></b>
# <table class="roundy" style="background:#FFF;" width="100%">
# <tbody><tr>
# <td>[[|<span style="color:#000;"></span>]]
# </td>
# <td style="display:none;" width="50%">[[|<span style="color:#000;"></span>]]
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="roundy" style="background:#A7DB8D;"><b><a href="/wiki/Experience" title="Experience"><span style="color:#000;">Base experience yield</span></a></b>
# <table class="roundy" style="background:#FFF;" width="100%">
# <tbody><tr>
# <td width="50%">64<br/><small>Gen. I-IV</small>
# </td>
# <td style="display:none;">Unknown<br/><small>IV</small>
# </td>
# <td>64<br/><small>V+</small>
# </td></tr></tbody></table>
# </td>
# <td class="roundy" style="background:#A7DB8D;"><b><a href="/wiki/Experience" title="Experience"><span style="color:#000;">Leveling rate</span></a></b>
# <table class="roundy" style="background:#FFF; padding-top: 0.8em; padding-bottom: 0.8em;" width="100%">
# <tbody><tr>
# <td>Medium Slow
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="roundy" colspan="2" style="background:#A7DB8D;"><b><a href="/wiki/List_of_Pok%C3%A9mon_by_effort_value_yield" title="List of Pokémon by effort value yield"><span style="color:#000;">EV yield</span></a></b>
# <table class="roundy" style="background:#FFF;" width="100%">
# <tbody><tr>
# <td colspan="6">Total: 1
# </td></tr>
# <tr style="display:none;">
# <td colspan="6">Bulbasaur
# </td></tr>
# <tr>
# <td class="roundy" style="background:#FF5959;" width="16%">0<br/><small>HP</small>
# </td>
# <td class="roundy" style="background:#F5AC78;" width="17%">0<br/><small>Atk</small>
# </td>
# <td class="roundy" style="background:#FAE078;" width="16%">0<br/><small>Def</small>
# </td>
# <td class="roundy" style="background:#9DB7F5;" width="17%">1<br/><small>Sp.Atk</small>
# </td>
# <td class="roundy" style="background:#A7DB8D;" width="17%">0<br/><small>Sp.Def</small>
# </td>
# <td class="roundy" style="background:#FA92B2;" width="17%">0<br/><small>Speed</small>
# </td></tr>
# <tr style="display:none;">
# <td colspan="6">
# </td></tr>
# <tr style="display:none;">
# <td class="roundy" style="background:#FF5959;">0<br/><small>HP</small>
# </td>
# <td class="roundy" style="background:#F5AC78;">0<br/><small>Atk</small>
# </td>
# <td class="roundy" style="background:#FAE078;">0<br/><small>Def</small>
# </td>
# <td class="roundy" style="background:#9DB7F5;">0<br/><small>Sp.Atk</small>
# </td>
# <td class="roundy" style="background:#A7DB8D;">0<br/><small>Sp.Def</small>
# </td>
# <td class="roundy" style="background:#FA92B2;">0<br/><small>Speed</small>
# </td></tr>
# <tr style="display:none;">
# <td colspan="6">
# </td></tr>
# <tr style="display:none;">
# <td class="roundy" style="background:#FF5959;">0<br/><small>HP</small>
# </td>
# <td class="roundy" style="background:#F5AC78;">0<br/><small>Atk</small>
# </td>
# <td class="roundy" style="background:#FAE078;">0<br/><small>Def</small>
# </td>
# <td class="roundy" style="background:#9DB7F5;">0<br/><small>Sp.Atk</small>
# </td>
# <td class="roundy" style="background:#A7DB8D;">0<br/><small>Sp.Def</small>
# </td>
# <td class="roundy" style="background:#FA92B2;">0<br/><small>Speed</small>
# </td></tr>
# <tr style="display:none;">
# <td colspan="6">
# </td></tr>
# <tr style="display:none;">
# <td class="roundy" style="background:#FF5959;">0<br/><small>HP</small>
# </td>
# <td class="roundy" style="background:#F5AC78;">0<br/><small>Atk</small>
# </td>
# <td class="roundy" style="background:#FAE078;">0<br/><small>Def</small>
# </td>
# <td class="roundy" style="background:#9DB7F5;">0<br/><small>Sp.Atk</small>
# </td>
# <td class="roundy" style="background:#A7DB8D;">0<br/><small>Sp.Def</small>
# </td>
# <td class="roundy" style="background:#FA92B2;">0<br/><small>Speed</small>
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# <td class="roundy" style="background:#A7DB8D;"><b><a href="/wiki/List_of_Pok%C3%A9mon_by_shape" title="List of Pokémon by shape"><span style="color:#000;">Shape</span></a></b>
# <table class="roundy" style="background:#FFF;" width="100%">
# <tbody><tr>
# <td><a class="image" href="/wiki/File:Body08.png"><img alt="Body08.png" decoding="async" height="32" loading="lazy" src="//archives.bulbagarden.net/media/upload/thumb/c/cc/Body08.png/32px-Body08.png" srcset="//archives.bulbagarden.net/media/upload/thumb/c/cc/Body08.png/48px-Body08.png 1.5x, //archives.bulbagarden.net/media/upload/thumb/c/cc/Body08.png/64px-Body08.png 2x" width="32"/></a>
# </td></tr></tbody></table>
# </td>
# <td class="roundy" style="background:#A7DB8D;"><b><a href="/wiki/Footprint" title="Footprint"><span style="color:#000;">Footprint</span></a></b>
# <table class="roundy" style="background:#FFF; padding-top:6px; padding-bottom:7px;" width="100%">
# <tbody><tr>
# <td><a class="image" href="/wiki/File:F0001.png"><img alt="F0001.png" decoding="async" height="16" loading="lazy" src="//archives.bulbagarden.net/media/upload/d/d1/F0001.png" width="16"/></a>
# </td>
# <td style="display:none;" width="50%"><a class="image" href="/wiki/File:None.png"><img alt="None.png" decoding="async" height="1" loading="lazy" src="//archives.bulbagarden.net/media/upload/e/e3/None.png" width="1"/></a><br/><small>{{{form2}}}</small>
# </td></tr></tbody></table>
# </td></tr>
# <tr>
# ...
# </td></tr></tbody></table>
# </td>
# <td width="20%">
# <table cellspacing="1" class="roundy" style="background: #D4924B; border: 2px solid #8A5F31" width="100%">
# <tbody><tr>
# <th class="roundy" colspan="2" style="background: #E3B88A"><a href="/wiki/Pok%C3%A9mon:_Let%27s_Go,_Pikachu!_and_Let%27s_Go,_Eevee!" title="Pokémon: Let's Go, Pikachu! and Let's Go, Eevee!"><span style="color:#000;">Let's Go, Eevee!</span></a>
# </th></tr>
# <tr>
# <td class="roundyleft" height="90px" style="background: #FFF" width="50%"><a href="/wiki/Partner_Pok%C3%A9mon_(game)" title="Partner Pokémon (game)"><img alt="0133Eevee LG.png" decoding="async" height="48" loading="lazy" src="//archives.bulbagarden.net/media/upload/thumb/8/8e/0133Eevee_LG.png/48px-0133Eevee_LG.png" srcset="//archives.bulbagarden.net/media/upload/thumb/8/8e/0133Eevee_LG.png/72px-0133Eevee_LG.png 1.5x, //archives.bulbagarden.net/media/upload/thumb/8/8e/0133Eevee_LG.png/96px-0133Eevee_LG.png 2x" width="48"/></a><br/><a href="/wiki/Eevee_(Pok%C3%A9mon)" title="Eevee (Pokémon)">Eevee</a> <small>(<a href="/wiki/Partner_Pok%C3%A9mon_(game)" title="Partner Pokémon (game)">player</a>)</small>
# </td>
# <td class="roundyright" style="background: #FFF" width="50%"><a href="/wiki/Pikachu_(Pok%C3%A9mon)" title="Pikachu (Pokémon)"><img alt="0025Pikachu.png" decoding="async" height="48" loading="lazy" src="//archives.bulbagarden.net/media/upload/thumb/4/4a/0025Pikachu.png/48px-0025Pikachu.png" srcset="//archives.bulbagarden.net/media/upload/thumb/4/4a/0025Pikachu.png/72px-0025Pikachu.png 1.5x, //archives.bulbagarden.net/media/upload/thumb/4/4a/0025Pikachu.png/96px-0025Pikachu.png 2x" width="48"/></a><br/><a href="/wiki/Pikachu_(Pok%C3%A9mon)" title="Pikachu (Pokémon)">Pikachu</a> <small>(<a href="/wiki/Trace_(game)" title="Trace (game)">rival</a>)</small>
# </td></tr></tbody></table>
# </td></tr></tbody></table>
# <p><br clear="all"/>
# </p>
# <table style="background: #78C850; width: 100%; border: 3px solid #682A68; margin-bottom: 7px; border-radius: 20px; -moz-border-radius: 20px; -webkit-border-radius: 20px; -khtml-border-radius: 20px; -icab-border-radius: 20px; -o-border-radius: 20px;">
# <tbody><tr>
# <td style="width:45%; background: #A7DB8D; border-top-left-radius: 15px; -moz-border-radius-topleft: 15px; -webkit-border-top-left-radius: 15px; -khtml-border-top-left-radius: 15px; -icab-border-top-left-radius: 15px; -o-border-top-left-radius: 15px; border-bottom-left-radius: 15px; -moz-border-radius-bottomleft: 15px; -webkit-border-bottom-left-radius: 15px; -khtml-border-bottom-left-radius: 15px; -icab-border-bottom-left-radius: 15px; -o-border-bottom-left-radius: 15px;">
# <table style="width:100%; background: #A7DB8D; border-top-left-radius: 15px; -moz-border-radius-topleft: 15px; -webkit-border-top-left-radius: 15px; -khtml-border-top-left-radius: 15px; -icab-border-top-left-radius: 15px; -o-border-top-left-radius: 15px; border-bottom-left-radius: 15px; -moz-border-radius-bottomleft: 15px; -webkit-border-bottom-left-radius: 15px; -khtml-border-bottom-left-radius: 15px; -icab-border-bottom-left-radius: 15px; -o-border-bottom-left-radius: 15px;">
# <tbody><tr>
# <td style="text-align: right"><a href="/wiki/Miraidon_(Pok%C3%A9mon)" title="Miraidon (Pokémon)"><span style="color:#000;">←</span></a>
# </td>
# <td style="text-align: center"><a href="/wiki/Miraidon_(Pok%C3%A9mon)" title="Miraidon (Pokémon)"><img alt="1008Miraidon.png" decoding="async" height="40" loading="lazy" src="//archives.bulbagarden.net/media/upload/thumb/1/1c/1008Miraidon.png/40px-1008Miraidon.png" srcset="//archives.bulbagarden.net/media/upload/thumb/1/1c/1008Miraidon.png/60px-1008Miraidon.png 1.5x, //archives.bulbagarden.net/media/upload/thumb/1/1c/1008Miraidon.png/80px-1008Miraidon.png 2x" width="40"/></a>
# </td>
# <td style="text-align: right"><a href="/wiki/Miraidon_(Pok%C3%A9mon)" title="Miraidon (Pokémon)"><span style="color:#000;">#1008: Miraidon</span></a>
# </td></tr></tbody></table>
# </td>
# <td style="background: #A7DB8D;">
# <table style="background: #A7DB8D; width:100%;">
# <tbody><tr>
# <td style="text-align: center"><a href="/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number" title="List of Pokémon by National Pokédex number"><span style="color:#000;">Pokémon</span></a>
# </td></tr></tbody></table>
# </td>
# <td style="width:45%; background: #A7DB8D; border-top-right-radius: 15px; -moz-border-radius-topright: 15px; -webkit-border-top-right-radius: 15px; -khtml-border-top-right-radius: 15px; -icab-border-top-right-radius: 15px; -o-border-top-right-radius: 15px; border-bottom-right-radius: 15px; -moz-border-radius-bottomright: 15px; -webkit-border-bottom-right-radius: 15px; -khtml-border-bottom-right-radius: 15px; -icab-border-bottom-right-radius: 15px; -o-border-bottom-right-radius: 15px;">
# <table style="width:100%; background: #A7DB8D; border-top-right-radius: 15px; -moz-border-radius-topright: 15px; -webkit-border-top-right-radius: 15px; -khtml-border-top-right-radius: 15px; -icab-border-top-right-radius: 15px; -o-border-top-right-radius: 15px; border-bottom-right-radius: 15px; -moz-border-radius-bottomright: 15px; -webkit-border-bottom-right-radius: 15px; -khtml-border-bottom-right-radius: 15px; -icab-border-bottom-right-radius: 15px; -o-border-bottom-right-radius: 15px;">
# <tbody><tr>
# <td style="text-align: left"><a href="/wiki/Ivysaur_(Pok%C3%A9mon)" title="Ivysaur (Pokémon)"><span style="color:#000;">#0002: Ivysaur</span></a>
# </td>
# <td style="text-align: center"><a href="/wiki/Ivysaur_(Pok%C3%A9mon)" title="Ivysaur (Pokémon)"><img alt="0002Ivysaur.png" decoding="async" height="40" loading="lazy" src="//archives.bulbagarden.net/media/upload/thumb/8/81/0002Ivysaur.png/40px-0002Ivysaur.png" srcset="//archives.bulbagarden.net/media/upload/thumb/8/81/0002Ivysaur.png/60px-0002Ivysaur.png 1.5x, //archives.bulbagarden.net/media/upload/thumb/8/81/0002Ivysaur.png/80px-0002Ivysaur.png 2x" width="40"/></a>
# </td>
# <td style="text-align: left"><a href="/wiki/Ivysaur_(Pok%C3%A9mon)" title="Ivysaur (Pokémon)"><span style="color:#000;">→</span></a>
# </td></tr></tbody></table>
# </td></tr></tbody></table>
# <table style="margin:auto; background: #FAFFF4; border: 2px solid #8888AA; width: 100%; border-radius: 80px; -moz-border-radius: 80px; -webkit-border-radius: 80px; -khtml-border-radius: 80px; -icab-border-radius: 80px; -o-border-radius: 80px;">
# <tbody><tr>
# <td style="border-radius: 80px; -moz-border-radius: 80px; -webkit-border-radius: 80px; -khtml-border-radius: 80px; -icab-border-radius: 80px; -o-border-radius: 80px;; background: #FFFFFF;" width="60px"><a class="image" href="/wiki/File:Project_Pok%C3%A9dex_logo.png"><img alt="Project Pokédex logo.png" decoding="async" height="80" loading="lazy" src="//archives.bulbagarden.net/media/upload/thumb/9/95/Project_Pok%C3%A9dex_logo.png/80px-Project_Pok%C3%A9dex_logo.png" srcset="//archives.bulbagarden.net/media/upload/thumb/9/95/Project_Pok%C3%A9dex_logo.png/120px-Project_Pok%C3%A9dex_logo.png 1.5x, //archives.bulbagarden.net/media/upload/thumb/9/95/Project_Pok%C3%A9dex_logo.png/160px-Project_Pok%C3%A9dex_logo.png 2x" width="80"/></a>
# </td>
# <td>This Pokémon article is part of <b><a href="/wiki/Bulbapedia:Project_Pok%C3%A9dex" title="Bulbapedia:Project Pokédex">Project Pokédex</a></b>, a <a href="/wiki/Bulbapedia:Projects" title="Bulbapedia:Projects">Bulbapedia project</a> that aims to write comprehensive articles on each Pokémon as a species.
# </td></tr></tbody></table>
# </div>
# <script>
# // Initialize elements
# appendElementIf({id: "adthrive-left-s", wAbove: 1520, wBelow: 1699, hAbove: 700});
# appendElementIf({id: "adthrive-left-m", wAbove: 1700, wBelow: 1890, hAbove: 700});
# appendElementIf({id: "adthrive-left-l", wAbove: 1891, hAbove: 700});
#
# appendElementIf({id: "adthrive-right-s", wAbove: 945, wBelow: 1099, hAbove: 964});
# appendElementIf({id: "adthrive-right-m", wAbove: 1100, wBelow: 1399, hAbove: 964});
# appendElementIf({id: "adthrive-right-l", wAbove: 1400, hAbove: 964});
# appendElementIf({id: "adthrive-right-rect", hBelow: 964});
#
#
# // Appends element if condition is met
# function appendElementIf({id, wAbove, wBelow, hAbove, hBelow}) {
#
# 	// find browser height
# 	var w = window.innerWidth;
# 	var h = window.innerHeight;
#
# 	// If true after browser size check then unit is added
# 	var condition = true;
#
# 	// Check size conditions
# 	if (wBelow && (w > wBelow)) condition = false;
# 	if (wAbove && (w < wAbove)) condition = false;
#
# 	if (hBelow && (h > hBelow)) condition = false;
# 	if (hAbove && (h < hAbove)) condition = false;
#
# 	// Append element if condition is met
# 	if (condition) {
# 		createAndAppendElement(id);
# 	}
# }
#
#
# // creates and appends a div element to the body
# function createAndAppendElement(id)
# {
# 	var atEl = document.createElement('div');
# 	atEl.id = id;
# 	document.body.appendChild(atEl);
# }
# </script>
# <style>
#         /*This styles are to place the close button right above the video without this the close button will be placed below the video.*/
#         #pw-close-btn {
#             display: none !important;
#         }
#         #span_btn {
#             position: absolute;
#             top: -40px;
#             right: 0;
#             cursor: pointer;
#         }
#         @media only screen and (max-width: 767px) {
#             #span_btn {
#                 top: 9px;
#                 right: 11px;
#             }
#         }
#         .is-docked {
#            margin-bottom:90px !important;
#         }
#         </style>
# <script>!function(){"use strict";!function(e){if(-1===e.cookie.indexOf("__adblocker")){e.cookie="__adblocker=; expires=Thu, 01 Jan 1970 00:00:00 GMT; path=/";var t=new XMLHttpRequest;t.open("GET","https://ads.adthrive.com/abd/abd.js",!0),t.onreadystatechange=function(){if(XMLHttpRequest.DONE===t.readyState)if(200===t.status){var a=e.createElement("script");a.innerHTML=t.responseText,e.getElementsByTagName("head")[0].appendChild(a)}else{var n=new Date;n.setTime(n.getTime()+3e5),e.cookie="__adblocker=true; expires="+n.toUTCString()+"; path=/"}},t.send()}}(document)}();</script>
# <script>!function(){"use strict";var e;e=document,function(){var t,n;function r(){var t=e.createElement("script");t.src="https://cafemedia-com.videoplayerhub.com/galleryplayer.js",e.head.appendChild(t)}function a(){var t=e.cookie.match("(^|[^;]+)\s*__adblocker\s*=\s*([^;]+)");return t&&t.pop()}function c(){clearInterval(n)}return{init:function(){var e;"true"===(t=a())?r():(e=0,n=setInterval((function(){100!==e&&"false"!==t||c(),"true"===t&&(r(),c()),t=a(),e++}),50))}}}().init()}();
# </script>
# </div><div class="printfooter">
# Retrieved from "<a dir="ltr" href="https://bulbapedia.bulbagarden.net/w/index.php?title=Bulbasaur_(Pokémon)&amp;oldid=3669068">https://bulbapedia.bulbagarden.net/w/index.php?title=Bulbasaur_(Pokémon)&amp;oldid=3669068</a>"</div>
# <div class="catlinks" data-mw="interface" id="catlinks"><div class="mw-normal-catlinks" id="mw-normal-catlinks"><a href="/wiki/Special:Categories" title="Special:Categories">Categories</a>: <ul><li><a href="/wiki/Category:Generation_I_Pok%C3%A9mon" title="Category:Generation I Pokémon">Generation I Pokémon</a></li><li><a href="/wiki/Category:Grass-type_Pok%C3%A9mon" title="Category:Grass-type Pokémon">Grass-type Pokémon</a></li><li><a href="/wiki/Category:Poison-type_Pok%C3%A9mon" title="Category:Poison-type Pokémon">Poison-type Pokémon</a></li><li><a href="/wiki/Category:Dual-type_Pok%C3%A9mon" title="Category:Dual-type Pokémon">Dual-type Pokémon</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_with_a_gender_ratio_of_seven_males_to_one_female" title="Category:Pokémon with a gender ratio of seven males to one female">Pokémon with a gender ratio of seven males to one female</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_in_the_Medium_Slow_experience_group" title="Category:Pokémon in the Medium Slow experience group">Pokémon in the Medium Slow experience group</a></li><li><a href="/wiki/Category:Green-colored_Pok%C3%A9mon" title="Category:Green-colored Pokémon">Green-colored Pokémon</a></li><li><a href="/wiki/Category:Body_style_08_Pok%C3%A9mon" title="Category:Body style 08 Pokémon">Body style 08 Pokémon</a></li><li><a href="/wiki/Category:Monster_group_Pok%C3%A9mon" title="Category:Monster group Pokémon">Monster group Pokémon</a></li><li><a href="/wiki/Category:Grass_group_Pok%C3%A9mon" title="Category:Grass group Pokémon">Grass group Pokémon</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_in_the_Kanto_Pok%C3%A9dex" title="Category:Pokémon in the Kanto Pokédex">Pokémon in the Kanto Pokédex</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_in_the_Johto_Pok%C3%A9dex" title="Category:Pokémon in the Johto Pokédex">Pokémon in the Johto Pokédex</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_in_the_Kalos_Pok%C3%A9dex" title="Category:Pokémon in the Kalos Pokédex">Pokémon in the Kalos Pokédex</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_in_the_Galar_Pok%C3%A9dex" title="Category:Pokémon in the Galar Pokédex">Pokémon in the Galar Pokédex</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_with_wild_held_items" title="Category:Pokémon with wild held items">Pokémon with wild held items</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_with_a_base_stat_total_of_318" title="Category:Pokémon with a base stat total of 318">Pokémon with a base stat total of 318</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_whose_Special_stat_became_both_Special_Attack_and_Special_Defense" title="Category:Pokémon whose Special stat became both Special Attack and Special Defense">Pokémon whose Special stat became both Special Attack and Special Defense</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_with_17_max_performance_stars" title="Category:Pokémon with 17 max performance stars">Pokémon with 17 max performance stars</a></li><li><a href="/wiki/Category:Body_size_1_Pok%C3%A9mon" title="Category:Body size 1 Pokémon">Body size 1 Pokémon</a></li><li><a href="/wiki/Category:Pok%C3%A9mon_that_are_part_of_a_three-stage_evolutionary_line" title="Category:Pokémon that are part of a three-stage evolutionary line">Pokémon that are part of a three-stage evolutionary line</a></li><li><a href="/wiki/Category:Starter_Pok%C3%A9mon" title="Category:Starter Pokémon">Starter Pokémon</a></li><li><a href="/wiki/Category:Mystery_Dungeon_starters" title="Category:Mystery Dungeon starters">Mystery Dungeon starters</a></li><li><a href="/wiki/Category:Anime_starter_Pok%C3%A9mon" title="Category:Anime starter Pokémon">Anime starter Pokémon</a></li></ul></div></div><div class="visualClear"></div></div></div><div class="visualClear"></div></div><div dir="ltr" id="column-one" lang="en"><h2>Navigation menu</h2><div aria-labelledby="p-personal-label" class="portlet" id="p-personal" role="navigation"><h3 dir="ltr" id="p-personal-label" lang="en">Personal tools</h3><div class="pBody ...
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"3.160","walltime":"15.023","ppvisitednodes":{"value":34292,"limit":1000000},"postexpandincludesize":{"value":682505,"limit":2097152},"templateargumentsize":{"value":78102,"limit":2097152},"expansiondepth":{"value":11,"limit":40},"expensivefunctioncount":{"value":1,"limit":100},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":2276,"limit":5000000},"timingprofile":["100.00% 5657.470      1 -total","  8.81%  498.548      1 Template:TypeEffectiveness","  7.08%  400.669     72 Template:Type_effectiveness_entry","  6.27%  354.994     33 Template:Learnlist/prevgen8","  6.12%  346.245     22 Template:EventAvail","  5.17%  292.638      9 Template:Availability/Entry2/None","  5.06%  286.522      1 Template:Starter_Pokémon","  4.56%  257.922     26 Template:Availability/Entry1","  3.97%  224.352    289 Template:Color","  3.56%  201.564      1 Template:Stats"]},"cachereport":{"timestamp":"20230215000819","ttl":86400,"transientcontent":false}}});mw.config.set({"wgBackendResponseTime":15894});});</script></body></html>

# %%
# pokemon_text_lst = []
# biology_span = entry_soup.find("span",id="Biology").next_elements
# for i, element in enumerate(biology_span):
#     if i == 0:
#         continue
#     if element.name == "h2": # next section
#         break
#     pokemon_text_lst.append(element.get_text(strip=True))

# %%
# pokemon_text = ' '.join(pokemon_text_lst).strip()
# vocab = spacy.load('en_core_web_sm')
# doc = vocab(pokemon_text)
# tokens = set()
# for token in doc:
#     if token.pos_ == 'NOUN':
#         tokens.add(token.text)
# nouns = " ".join(tokens)
# Out:
# {'Bulbasaur',
#  'abandonment',
#  'air',
#  'amphibian',
#  'anime',
#  'animehave',
#  'back',
#  'birth',
#  'bulb',
#  'by',
#  'ceremony',
#  'claws',
#  'ear',
#  'energy',
#  'eyes',
#  'forests',
#  'garden',
#  'gather',
#  'grasslands',
#  'head',
#  'individual',
#  'ingrasslandsand',
#  'instinct',
#  'jaw',
#  'legs',
#  'mouth',
#  'ownership',
#  'pair',
#  'patches',
#  'photosynthesis',
#  'plant',
#  'pupils',
#  'region',
#  'seed',
#  'seeds',
#  'skin',
#  'snout',
#  'status',
#  'structures',
#  'teeth',
#  'tentacle',
#  'term',
#  'theKantoregion',
#  'top',
#  'transformation',
#  'vines',
#  'wild',
#  'year'}

# %%
# Out:
# 'skin legs instinct anime ingrasslandsand eyes garden photosynthesis region structures ownership head year amphibian by Bulbasaur forests patches tentacle claws pupils ear seeds wild back animehave vines bulb ceremony teeth plant status seed grasslands abandonment theKantoregion snout mouth energy pair jaw air term individual birth transformation top gather'

# %% [markdown]
# ---

# %%
# bulbapedia_pokemon_table.to_csv("bulbapedia.csv")

# %%
# pokemon.to_csv("pokemon.csv")
